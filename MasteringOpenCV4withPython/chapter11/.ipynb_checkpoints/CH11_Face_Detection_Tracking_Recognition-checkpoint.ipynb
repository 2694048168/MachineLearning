# %% [markdown]
# # Face Detection, Tracking, and Recognition

# %%
# $ pip install dlib-19.8.1-cp36-cp36m-win_amd64.whl
# The wheel filename is {distribution}-{version}(-{build tag})?-{python tag}-{abi tag}-{platform tag}.whl

# pip install --upgrade dlib
# http://dlib.net/python/index.html
# https://pypi.org/project/dlib/
# https://github.com/davisking/dlib

# $ pip install face_recognition
# https://pypi.org/project/face-recognition/
# https://github.com/ageitgey/face_recognition

# pip install --upgrade cvlib
# https://pypi.org/project/cvlib/
# https://github.com/arunponnusamy/cvlib
# https://www.cvlib.net/

# %% [markdown]
# ## Face processing introduction

# %%
from IPython.display import Image, display
display(Image(filename="./diagram.png", embed=True))

# %% [markdown]
# ## Face detection

# %% [raw]
# Face detection is a specific case of object detection, where the task is to
# find both the locations and sizes of all the faces in an image.

# %%
# https://docs.opencv.org/4.5.2/db/d28/tutorial_cascade_classifier.html
# Haar feature-based cascade classifiers can be used to detect objects other than human faces.

# face_detection_opencv_haar.py

# https://github.com/opencv/opencv/tree/master/data/haarcascades

# cat_face_detection_opencv_haar.py 

#  OpenCV provides a deep learning-based face detector 
# https://github.com/opencv/opencv/tree/master/samples/dnn/face_detector

# face_detection_opencv_dnn.py

# Face detection with dlib
# train_object_detector.py
#  face_detection_dlib_hog.py
# face_detection_dlib_cnn.py

# Face detection with face_recognition
# face_detection_fr_hog.py
# face_detection_fr_cnn.py

# Face detection with cvlib
# import cvlib as cv
# face_detection_cvlib_dnn.py
# https://github.com/arunponnusamy/cvlib/blob/master/cvlib/face_detection.py

# %% [markdown]
# ## Facial landmarks detection

# %% [raw]
# Facial landmarks detection is a specific case of landmarks detection,
# where the task is to locate the main landmarks in a face.

# %%
# A facial landmark detection algorithm aims to automatically 
# identify the locations of the facial landmark points in images or videos. 

# Detecting facial landmarks with OpenCV
# https://docs.opencv.org/4.5.2/db/dd8/classcv_1_1face_1_1Facemark.html

# Detecting facial landmarks with dlib
# landmarks_detection_dlib.py

# Detecting facial landmarks with face_recognition
# landmarks_detection_fr.py

# %% [markdown]
# ## Face tracking

# %% [raw]
# Face tracking is a specific case of object tracking, where the task is to
# find both the locations and sizes of all the moving faces in a video by
# taking into account the extra information that can be extracted in consecutive frames of the video.

# %%
# https://www.votchallenge.net/vot2014/download/vot_2014_presentation.pdf

# Face tracking with the dlib DCF-based tracker
# face_tracking_correlation_filters.py
# This method updates the tracker and returns the peak-to-side-lobe ratio, 
# which is a metric that measures how confident the tracker is. 

# Object tracking with the dlib DCF-based tracker
# face_tracking_correlation_filters.py

# %% [markdown]
# ## Face recognition

# %% [raw]
# Face recognition is a specific case of object recognition,
# where a person is identified or verified from an image or video using the information extracted from the face:
#   - Face identification (1:N): The task is to find the closest match from an unknown person in a collection of known faces.
#   - Face verification (1:1): The task is to check whether the person is who they claim to be.

# %%
# Face recognition with OpenCV
# https://docs.opencv.org/4.5.2/dd/d65/classcv_1_1face_1_1FaceRecognizer.html

# Face recognition with dlib
# https://github.com/davisking/dlib-models/blob/master/dlib_face_recognition_resnet_model_v1.dat.bz2
# encode_face_dlib.py 
# compare_faces_dlib.py

# Face recognition with face_recognition
# encode_face_fr.py
