# %% [markdown]
# # Chapter 01 Introduction to OpenCV and Python

# %%
# Additional Python libraries and packages for AI and machine learning can be found at
# https://python.libhunt.com/packages/artificial-intelligence

# %% [markdown]
# ## The OpenCV and Python project structure

# %%
from IPython.display import Image, display
display(Image(filename="./projectStructure.png", embed=True))
display(Image(filename="./README.png", embed=True))

# %%
# https://github.com/dbader/readme-template
# https://github.com/github/gitignore/blob/master/Python.gitignore

# %%
# $ pip freeze > requirements.txt
# $ pip install -r requirements.txt

# https://pip.pypa.io/en/stable/user_guide/#requirements-files

# %%
# https://packaging.python.org/tutorials/packaging-projects/
# https://github.com/pypa/sampleproject/blob/master/setup.py
# https://www.pypa.io/en/latest/

# how to write setup.py file for projects

# $ python setup.py install
# $ pip install -e path_to_setup.py

# %%
# $ python -m pip install --upgrade pip
# $ pip install --upgrade jupyterlab
# $ pip install -U jupyterlab

# %%
# Additionally, conda can be used to create and manage virtual environments.
# $ conda create --name vistualEnvName
# $ activate test
# $ deactivate
# $ conda remove vistualEnvName --all

# %%
# pip virtualenv can be used to create and manage virtual environments
# $ pip install virtualenv
# $ virtualenv vistualEnvName
# $ ~/vistualEnvName/Scripts/activate
# $ deactivate
# $ rmvirtualenv vistualEnvName
