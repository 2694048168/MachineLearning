# %% [markdown]
# # Thresholding Techniques

# %% [markdown]
# ## Introducing thresholding techniques

# %%
# thresholding_introduction.py

# %% [markdown]
# ## Simple thresholding

# %%
# cv2.threshold() function
# cv2.threshold(src, thresh, maxval, type, dst=None) -> retval, dst

# %%
from IPython.display import Image, display
display(Image(filename="./BINARY.PNG", embed=True))
display(Image(filename="./BINARY_INV.PNG", embed=True))
display(Image(filename="./TRUNC.PNG", embed=True))
display(Image(filename="./TOZERO.PNG", embed=True))
display(Image(filename="./TOZERO_INV.PNG", embed=True))

# %%
# thresholding_simple_types.py

# %% [markdown]
# ## Simple thresholding applied to a real image

# %%
# thresholding_example.py 
# thresholding_example_arange.py

# %% [markdown]
# ## Adaptive thresholding

# %%
# adaptiveThreshold(src, maxValue, adaptiveMethod, thresholdType, blockSize, C[, dst]) -> dst

# thresholding_adaptive.py
# thresholding_adaptive_filter_noise.py

# %%
from IPython.display import Image, display
display(Image(filename="./adaThre.png", embed=True))

# %% [markdown]
# ## Otsu's thresholding algorithm

# %%
# thresholding_otsu.py
# thresholding_otsu_filter_noise.py

# %% [markdown]
# ## The triangle binarization algorithm

# %%
# thresholding_triangle_filter_noise.py

# %% [markdown]
# ## Thresholding color images

# %%
# thresholding_bgr.py

# %% [markdown]
# ## Thresholding algorithms using scikit-image

# %%
# https://scikit-image.org/docs/stable/install.html
# !pip install -U scikit-image
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already up-to-date: scikit-image in d:\miniconda\install\lib\site-packages (0.18.1)
# ...

# %% [markdown]
# ## Introducing thresholding with scikit-image

# %%
import skimage

print("The version of scikit-image: {}".format(skimage.__version__))
# Out:
# The version of scikit-image: 0.18.1

# %%
# thresholding_scikit_image_otsu.py

# %% [markdown]
# ## Trying out more thresholding techniques with scikit-image

# %%
# thresholding_scikit_image_techniques.py 

# https://scikit-image.org/docs/dev/api/api.html
