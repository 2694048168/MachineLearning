# %% [markdown]
# # Introduction to Deep Learning

# %%
from IPython.display import display, Image
display(Image(filename='./diagram.png', embed=True))

# %% [markdown]
# ## Deep learning for image classification

# %%
from IPython.display import display, Image
display(Image(filename='./imagenet.png', embed=True))

# %% [markdown]
# ## Deep learning for object detection

# %%
#  benchmark object detection algorithms datasets
# 1. http://host.robots.ox.ac.uk/pascal/VOC/
# 2. ImageNet has released an object detection dataset since 2013
# 3. https://cocodataset.org/

# %%
from IPython.display import display, Image
display(Image(filename='./COCO.png', embed=True))

# %% [markdown]
# ## Deep learning in OpenCV

# %%
# blob_from_image.py
# blob_from_images.py 
# blob_from_images_cropping.py

# OpenCV deep learning classification

# %% [markdown]
# ## Introduction example to TensorFlow
