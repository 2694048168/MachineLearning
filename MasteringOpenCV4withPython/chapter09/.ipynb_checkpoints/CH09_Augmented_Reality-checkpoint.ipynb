# %% [markdown]
# # Augmented Reality

# %% [raw]
# Augmented reality is one of the hottest trends at present.
# The concept of augmented reality can be defined as an improved version of reality,
# where the view of the real world is enhanced with superimposed computer-generated elements
# (for example, images, videos,or 3D models, among others).
# In order to overlay and integrate digital information—augmenting reality,
# different types of techniques can be used,
# mainly location-based and recognition-based approaches.

# %% [markdown]
# ## An introduction to augmented reality

# %% [raw]
# - Location-based augmented reality
# - recognition-based augmented reality
#   - Marker-based pose estimation
#   - Markerless-based pose estimation ---> Perspective-n-Point (PnP)

# %% [markdown]
# ## 1. Markerless-based augmented reality

# %% [markdown]
# ### Feature detection

# %%
# feature_detection.py

# %%
from IPython.display import Image, display
display(Image(filename="./features.png", embed=True))

# %% [markdown]
# ### Feature matching

# %%
# feature_matching.py

# %%
from IPython.display import Image, display
display(Image(filename="./matching.png", embed=True))

# %% [markdown]
# ### Feature matching and homography computation to find objects

# %%
# feature_matching_object_recognition.py

# %% [markdown]
# ## 2. Marker-based augmented reality

# %% [markdown]
# ### Creating markers and dictionaries

# %%
# ArUco marker 2014年

# aruco_create_markers.py

# %% [markdown]
# ### Detecting markers

# %%
# aruco_detect_markers.py

# %% [markdown]
# ### Camera calibration

# %%
# aruco_camera_calibration.py

# %% [markdown]
# ### aruco_camera_calibration.py

# %%
# aruco_detect_markers_pose.py

# %% [markdown]
# ### Camera pose estimation and basic augmentation

# %%
# aruco_detect_markers_draw_square.py

# %% [markdown]
# ### Camera pose estimation and more advanced augmentation

# %%
# aruco_detect_markers_draw_square.py
# aruco_detect_markers_augmented_reality.py

# %%
# http://pyopengl.sourceforge.net/
# OpenGL for Python
