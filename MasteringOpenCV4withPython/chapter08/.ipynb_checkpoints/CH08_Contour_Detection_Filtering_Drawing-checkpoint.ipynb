# %% [markdown]
# # Contour Detection, Filtering, and Drawing

# %%
# the array_to_tuple() function, which converts an array into a tuple:
def array_to_tuple(arr):
  """Converts array to tuple"""
  return tuple(arr.reshape(1, -1)[0])

# %%
# contours_introduction.py

# contours_introduction_2.py

# cv2.findContours(image, mode, method[, contours[, hierarchy[, offset]]]) -> image, contours, hierarchy

# %% [markdown]
# ## Compressing contours

# %%
# contours_approximation_method.py

# %% [markdown]
# ## Image moments
#
# ### 统计学中的矩的概念

# %% [raw]
# In mathematics, a moment can be seen as a specific quantitative measure of a function shape.
# An image moment can be seen as a weighted average of image pixel intensities,
# or a function of such moments, encoding some interesting properties.

# %% [markdown]
# ## Some object features based on moments

# %%
# contours_analysis.py
# contours_ellipses.py

# %% [markdown]
# ## Hu moment invariants

# %%
# contours_hu_moments.py
# contours_hu_moments_properties.py

# %% [markdown]
# ## Zernike moments

# %% [markdown]
# ## More functionality related to contours

# %%
# contours_functionality.py

# %% [markdown]
# ## Filtering contours

# %%
# contours_sort_size.py

# %% [markdown]
# ## Recognizing contours

# %%
# using the Douglas-Peucker algorithm
# contours_shape_recognition.py

# %% [markdown]
# ## Matching contours

# %%
# contours_matching.py

# %%
from IPython.display import Image, display
display(Image(filename="./match.png", embed=True))
