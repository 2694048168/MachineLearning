# %% [markdown]
# # TensorFlow Guide

# %%
from IPython.display import Image, display

display(Image(filename='./image/essentialDocs.png', embed=True))

# %%
from IPython.display import Image, display

display(Image(filename='./image/libraryExtensions.png', embed=True))
display(Image(filename='./image/continue.png', embed=True))

# %% [markdown]
# ### TensorFlow 2 focuses on simplicity and ease of use,
# ### with updates like eager execution, intuitive higher-level APIs,
# ### and flexible model building on any platform.

# %% [markdown]
# # reference
#
# ### https://tensorflow.google.cn/guide
