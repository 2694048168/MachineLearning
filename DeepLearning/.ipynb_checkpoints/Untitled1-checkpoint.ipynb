# %%
import pandas as pd

df = pd.read_csv("./dataset/breast_cancer.csv")
df.shape
# Out:
# (569, 4)

# %%
df.head()
# Out:
#                                                                                                                                                                                                         569  \
# 17.99 10.38 122.80 1001.0 0.11840 0.27760 0.3001 0.14710 0.2419 0.07871 1.0950 0.9053 8.589 153.40 0.006399 0.04904 0.05373 0.01587 0.03003 0.006193 25.38 17.33 184.60 2019.0 0.1622 0.6656 0.7119  0.2654
# 20.57 17.77 132.90 1326.0 0.08474 0.07864 0.0869 0.07017 0.1812 0.05667 0.5435 0.7339 3.398 74.08  0.005225 0.01308 0.01860 0.01340 0.01389 0.003532 24.99 23.41 158.80 1956.0 0.1238 0.1866 0.2416  0.1860
# 19.69 21.25 130.00 1203.0 0.10960 0.15990 0.1974 0.12790 0.2069 0.05999 0.7456 0.7869 4.585 94.03  0.006150 0.04006 0.03832 0.02058 0.02250 0.004571 23.57 25.53 152.50 1709.0 0.1444 0.4245 0.4504  0.2430
# ...

# %% [markdown]
# ### 根据历史女性乳腺癌患者数据集（医学指标）构建分类模型进行良／恶性乳腺癌肿瘤预测
#
# ### 数据集源于威斯康星州临床科学中心。每个记录代表一个乳腺癌的随访数据样本
#
# ### 医学特征说明
#
# ![title](./image/feature.png)

# %%
import numpy as np

column_names = ['样本代码','肿块厚度','均匀细胞大小','均匀细胞形状','边缘粘连','单一上皮细胞大小','裸核', '乏味染色体','正常核','有丝分裂','分类']
data = pd.read_csv("./dataset/breast_cancer.csv", names=column_names)
data.tail()
# Out:
#       样本代码   肿块厚度 均匀细胞大小 均匀细胞形状     边缘粘连  单一上皮细胞大小       裸核    乏味染色体     正常核  \
# 565  21.56  22.39    142   1479  0.11100   0.11590  0.24390  0.13890  0.1726
# 566  20.13  28.25  131.2   1261  0.09780   0.10340  0.14400  0.09791  0.1752
# 567  16.60  28.08  108.3  858.1  0.08455   0.10230  0.09251  0.05302  0.1590
# 568  20.60  29.33  140.1   1265  0.11780   0.27700  0.35140  0.15200  0.2397
# 569   7.76  24.54  47.92    181  0.05263   0.04362  0.00000  0.00000  0.1587
#
#         有丝分裂      分类
# 565  0.05623  1.1760
# 566  0.05533  0.7655
# 567  0.05648  0.4564
# 568  0.07016  0.7260
# 569  0.05884  0.3857

# %%
data["分类"].min()
# Out:
# 0.1115

# %%
data["分类"].max()
# Out:
# 2.873
