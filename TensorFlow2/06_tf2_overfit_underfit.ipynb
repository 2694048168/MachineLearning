# %% [markdown]
# # Overfit and underfit

# %% [markdown]
# ## i. Setup

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)
# Out:
# 2.4.1

# %%
# git clone git@github.com:tensorflow/docs.git
# cd docs/
# pip install -e .
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from  IPython import display
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pathlib
import shutil
import tempfile

# %%
logdir = pathlib.Path.cwd()/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %%
logdir
# Out:
# WindowsPath('D:/miniconda/workspace/TensorFlow2/tensorboard_logs')

# %% [markdown]
# ## ii. The Higgs Dataset

# %%
# gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')

# Downloading data from http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz

# and then fetch HIGGS.csv.gz to ./ dir

gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'file:./HIGGS.csv.gz')

# %%
FEATURES = 28

# %%
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

# %%
def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
for features,label in packed_ds.batch(1000).take(1):
  print(features[0])
  plt.figure(figsize=(8,6), dpi=90)
  plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
train_ds
# Out:
# <CacheDataset shapes: ((28,), ()), types: (tf.float32, tf.float32)>

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %% [markdown]
# ## iii. Demonstrate overfitting

# %% [markdown]
# ### 1. Training procedure

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6), dpi=90)
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.losses.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
  return history

# %% [markdown]
# ### 2. Tiny model

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0026s vs `on_train_batch_end` time: 0.0187s). Check your callbacks.
#
# Epoch: 0, accuracy:0.4701,  binary_crossentropy:0.7541,  loss:0.7541,  val_accuracy:0.4540,  val_binary_crossentropy:0.7394,  val_loss:0.7394,
# ....................................................................................................
# Epoch: 100, accuracy:0.5984,  binary_crossentropy:0.6244,  loss:0.6244,  val_accuracy:0.5910,  val_binary_crossentropy:0.6282,  val_loss:0.6282,
# ....................................................................................................
# Epoch: 200, accuracy:0.6214,  binary_crossentropy:0.6115,  loss:0.6115,  val_accuracy:0.6250,  val_binary_crossentropy:0.6183,  val_loss:0.6183,
# ....................................................................................................
# Epoch: 300, accuracy:0.6392,  binary_crossentropy:0.6010,  loss:0.6010,  val_accuracy:0.6310,  val_binary_crossentropy:0.6089,  val_loss:0.6089,
# ....................................................................................................
# Epoch: 400, accuracy:0.6503,  binary_crossentropy:0.5938,  loss:0.5938,  val_accuracy:0.6390,  val_binary_crossentropy:0.6041,  val_loss:0.6041,
# ....................................................................................................
# Epoch: 500, accuracy:0.6610,  binary_crossentropy:0.5879,  loss:0.5879,  val_accuracy:0.6460,  val_binary_crossentropy:0.5995,  val_loss:0.5995,
# ....................................................................................................
# Epoch: 600, accuracy:0.6655,  binary_crossentropy:0.5840,  loss:0.5840,  val_accuracy:0.6560,  val_binary_crossentropy:0.5960,  val_loss:0.5960,
# ....................................................................................................
# Epoch: 700, accuracy:0.6642,  binary_crossentropy:0.5820,  loss:0.5820,  val_accuracy:0.6430,  val_binary_crossentropy:0.5971,  val_loss:0.5971,
# ....................................................................................................
# Epoch: 800, accuracy:0.6742,  binary_crossentropy:0.5790,  loss:0.5790,  val_accuracy:0.6610,  val_binary_crossentropy:0.5953,  val_loss:0.5953,
# ....................................................................................................
# Epoch: 900, accuracy:0.6742,  binary_crossentropy:0.5769,  loss:0.5769,  val_accuracy:0.6550,  val_binary_crossentropy:0.5973,  val_loss:0.5973,
# ....................................................................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %% [markdown]
# ### 3. Small model

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 16)                464
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0027s vs `on_train_batch_end` time: 0.0829s). Check your callbacks.
#
# Epoch: 0, accuracy:0.4884,  binary_crossentropy:0.9256,  loss:0.9256,  val_accuracy:0.4880,  val_binary_crossentropy:0.7814,  val_loss:0.7814,
# ....................................................................................................
# Epoch: 100, accuracy:0.6212,  binary_crossentropy:0.6181,  loss:0.6181,  val_accuracy:0.6190,  val_binary_crossentropy:0.6129,  val_loss:0.6129,
# ....................................................................................................
# Epoch: 200, accuracy:0.6599,  binary_crossentropy:0.5933,  loss:0.5933,  val_accuracy:0.6470,  val_binary_crossentropy:0.5922,  val_loss:0.5922,
# ....................................................................................................
# Epoch: 300, accuracy:0.6712,  binary_crossentropy:0.5835,  loss:0.5835,  val_accuracy:0.6520,  val_binary_crossentropy:0.5905,  val_loss:0.5905,
# ....................................................................................................
# Epoch: 400, accuracy:0.6829,  binary_crossentropy:0.5750,  loss:0.5750,  val_accuracy:0.6630,  val_binary_crossentropy:0.5910,  val_loss:0.5910,
# ....................................................................................................
# Epoch: 500, accuracy:0.6875,  binary_crossentropy:0.5683,  loss:0.5683,  val_accuracy:0.6710,  val_binary_crossentropy:0.5925,  val_loss:0.5925,
# ....................................................................................................
# Epoch: 600, accuracy:0.6905,  binary_crossentropy:0.5635,  loss:0.5635,  val_accuracy:0.6560,  val_binary_crossentropy:0.5911,  val_loss:0.5911,
# ....................................................................................................
# Epoch: 700, accuracy:0.6932,  binary_crossentropy:0.5597,  loss:0.5597,  val_accuracy:0.6580,  val_binary_crossentropy:0.5938,  val_loss:0.5938,
# .................

# %% [markdown]
# ### 4. Medium model

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                1856
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0028s vs `on_train_batch_end` time: 0.0874s). Check your callbacks.
#
# Epoch: 0, accuracy:0.4941,  binary_crossentropy:0.6940,  loss:0.6940,  val_accuracy:0.4940,  val_binary_crossentropy:0.6766,  val_loss:0.6766,
# ....................................................................................................
# Epoch: 100, accuracy:0.7077,  binary_crossentropy:0.5330,  loss:0.5330,  val_accuracy:0.6530,  val_binary_crossentropy:0.6071,  val_loss:0.6071,
# ....................................................................................................
# Epoch: 200, accuracy:0.7790,  binary_crossentropy:0.4411,  loss:0.4411,  val_accuracy:0.6330,  val_binary_crossentropy:0.6818,  val_loss:0.6818,
# ..............................................................

# %% [markdown]
# ### 5. Large model

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               14848
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0037s vs `on_train_batch_end` time: 0.0992s). Check your callbacks.
#
# Epoch: 0, accuracy:0.4968,  binary_crossentropy:0.8131,  loss:0.8131,  val_accuracy:0.5340,  val_binary_crossentropy:0.6798,  val_loss:0.6798,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0025,  loss:0.0025,  val_accuracy:0.6710,  val_binary_crossentropy:1.6935,  val_loss:1.6935,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0002,  loss:0.0002,  val_accuracy:0.6730,  val_binary_crossentropy:2.3022,  val_loss:2.3022,
# ...........................

# %% [markdown]
# ### 6. Plot the training and validation losses

# %%
plt.figure(figsize=(8,6), dpi=90)
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %% [markdown]
# ### 7. View in TensorBoard

# %% [raw]
# # These models all wrote TensorBoard logs during training.
# # Open an embedded TensorBoard viewer inside a notebook:
#
# # Load the TensorBoard notebook extension
# %load_ext tensorboard
#
# # Open an embedded TensorBoard viewer
# %tensorboard --logdir {logdir}/sizes

# %% [raw]
# # If you want to share TensorBoard results you can upload the logs to TensorBoard.dev
# # by copying the following into a code-cell.
#
# tensorboard dev upload --logdir  {logdir}/sizes

# %% [markdown]
# ### tensorboard --logdir ./tensorboard_logs/sizes
# ### http://localhost:6006/

# %% [markdown]
# ## iv. Strategies to prevent overfitting

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# WindowsPath('D:/miniconda/workspace/TensorFlow2/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %% [markdown]
# ### 1. Add weight regularization

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0042s vs `on_train_batch_end` time: 0.1028s). Check your callbacks.
#
# Epoch: 0, accuracy:0.5177,  binary_crossentropy:0.8250,  loss:2.3458,  val_accuracy:0.4760,  val_binary_crossentropy:0.6965,  val_loss:2.1423,
# ....................................................................................................
# Epoch: 100, accuracy:0.6504,  binary_crossentropy:0.6001,  loss:0.6232,  val_accuracy:0.6330,  val_binary_crossentropy:0.5934,  val_loss:0.6162,
# ....................................................................................................
# Epoch: 200, accuracy:0.6739,  binary_crossentropy:0.5828,  loss:0.6044,  val_accuracy:0.6410,  val_binary_crossentropy:0.5891,  val_loss:0.6107,
# ....................................................................................................
# Epoch: 300, accuracy:0.6782,  binary_crossentropy:0.5792,  loss:0.6030,  val_accuracy:0.6670,  val_binary_crossentropy:0.5823,  val_loss:0.6060,
# ....................................................................................................
# Epoch: 400, accuracy:0.6878,  binary_crossentropy:0.5671,  loss:0.5903,  val_accuracy:0.6500,  val_binary_crossentropy:0.5898,  val_loss:0.6131,
# ..............................................................

# %%
plt.figure(figsize=(8,6), dpi=90)
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
result = l2_model(features)
regularization_loss=tf.add_n(l2_model.losses)

# %% [markdown]
# ### 2. Add dropout

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0039s vs `on_train_batch_end` time: 0.1134s). Check your callbacks.
#
# Epoch: 0, accuracy:0.4990,  binary_crossentropy:0.8099,  loss:0.8099,  val_accuracy:0.4670,  val_binary_crossentropy:0.6882,  val_loss:0.6882,
# ....................................................................................................
# Epoch: 100, accuracy:0.6652,  binary_crossentropy:0.5959,  loss:0.5959,  val_accuracy:0.6790,  val_binary_crossentropy:0.5874,  val_loss:0.5874,
# ....................................................................................................
# Epoch: 200, accuracy:0.6834,  binary_crossentropy:0.5595,  loss:0.5595,  val_accuracy:0.6860,  val_binary_crossentropy:0.5878,  val_loss:0.5878,
# ..................................................................................................

# %%
plt.figure(figsize=(8,6), dpi=90)
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %% [markdown]
# ### 3. Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0038s vs `on_train_batch_end` time: 0.1213s). Check your callbacks.
#
# Epoch: 0, accuracy:0.5040,  binary_crossentropy:0.7988,  loss:0.9570,  val_accuracy:0.5680,  val_binary_crossentropy:0.6829,  val_loss:0.8404,
# ....................................................................................................
# Epoch: 100, accuracy:0.6510,  binary_crossentropy:0.6022,  loss:0.6314,  val_accuracy:0.6760,  val_binary_crossentropy:0.5818,  val_loss:0.6108,
# ....................................................................................................
# Epoch: 200, accuracy:0.6598,  binary_crossentropy:0.5880,  loss:0.6141,  val_accuracy:0.6860,  val_binary_crossentropy:0.5689,  val_loss:0.5950,
# ....................................................................................................
# Epoch: 300, accuracy:0.6717,  binary_crossentropy:0.5849,  loss:0.6132,  val_accuracy:0.6800,  val_binary_crossentropy:0.5645,  val_loss:0.5927,
# ....................................................................................................
# Epoch: 400, accuracy:0.6759,  binary_crossentropy:0.5779,  loss:0.6077,  val_accuracy:0.6850,  val_binary_crossentropy:0.5580,  val_loss:0.5879,
# ....................................................................................................
# Epoch: 500, accuracy:0.6778,  binary_crossentropy:0.5724,  loss:0.6043,  val_accuracy:0.6850,  val_binary_crossentropy:0.5538,  val_loss:0.5857,
# ....................................................................................................
# Epoch: 600, accuracy:0.6794,  binary_crossentropy:0.5697,  loss:0.6031,  val_accuracy:0.6910,  val_binary_crossentropy:0.5555,  val_loss:0.5889,
# ....................................................................................................
# Epoch: 700, accuracy:0.6863,  binary_crossentropy:0.5641,  loss:0.5987,  val_accuracy:0.6990,  val_binary_crossentropy:0.5490,  val_loss:0.5836,
# ....................................................................................................
# Epoch: 800, accuracy:0.6926,  binary_crossentropy:0.5595,  loss:0.5958,  val_accuracy:0.7060,  val_binary_crossentropy:0.5430,  val_loss:0.5792,
# ....................................................................................................
# Epoch: 900, accuracy:0.6881,  binary_crossentropy:0.5604,  loss:0.5981,  val_accuracy:0.6970,  val_binary_crossentropy:0.5388,  val_loss:0.5765,
# ....................................................................................................
# Epoch: 1000, accuracy:0.7012,  binary_crossentropy:0.5480,  loss:0.5873,  val_accuracy:0.7030,  val_binary_crossentropy:0.5400,  val_loss:0.5793,
# ....................................................................................................
# Epoch: 1100, accuracy:0.7000,  binary_crossentropy:0.5504,  loss:0.5909,  val_accuracy:0.7180,  val_binary_crossentropy:0.5494,  val_loss:0.5900,
# ....................................................................................................
# Epoch: 1200, accuracy:0.7064,  binary_crossentropy:0.5449,  loss:0.5868,  val_accuracy:0.6910,  val_binary_crossentropy:0.5428,  val_loss:0.5846,
# ....................

# %%
plt.figure(figsize=(8,6), dpi=90)
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %% [markdown]
# ### 4. View in TensorBoard

# %% [raw]
# %tensorboard --logdir {logdir}/regularizers

# %% [raw]
# tensorboard dev upload --logdir  {logdir}/regularizers

# %% [markdown]
# ## iv. Conclusions

# %% [markdown]
# # reference
#
# ### https://tensorflow.google.cn/tutorials/keras/overfit_and_underfit#view_in_tensorboard_2
